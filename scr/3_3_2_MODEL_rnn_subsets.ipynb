# %%
import pandas as pd
import numpy as np
import useful_functions as uf
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import SimpleRNN, Dense, Dropout, Input
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras.regularizers import l1_l2

# Possible datasets to test
file_paths = [
    #'../data/data_orig_parameters.csv'
    # '../data/BR_param_EDA.csv',
    #'../data/data_cleaned_RF.csv',
    '../data/data_cleaned_LASSO.csv',
    #'../data/data_cleaned_RFE.csv'
]

# List of outlier thresholds to test
outlier_thresholds = [np.nan, 0.05, 0.10, 0.15, 0.20]

# Dictionary to store the errors
errors_dict = {}

# Load the model from the file
best_model = load_model('best_rnn_model_grid_lasso_6.keras')
# from manual hyperparameter tuning
epochs = 75
batch_size = 128
patience = 6

# Loop through the files and outlier thresholds
for file_path in file_paths:
    print(f"REading File: {file_path}")
    for remove_outliers_threshold in outlier_thresholds:
        print(f"Outlier Threshold: {remove_outliers_threshold}")
        # Load  data
        df_raw = pd.read_csv(file_path, parse_dates=['Date'], index_col='Date')
        target_variable = df_raw.columns[0]
        # Convert all columns to float
        df_raw = df_raw.astype('float64')   
        df = df_raw.copy()

        # Remove outliers using the threshold
        if not pd.isna(remove_outliers_threshold):
            df_cleaned = uf.remove_outliers(df.copy(), threshold=remove_outliers_threshold)
        else:
            df_cleaned = df.copy()

        # Fill missing values
        df_adjusted = uf.fill_missing_values(df_cleaned)

        # Define test, train and validation set sizes
        val_size = 48 # 48 months or 4 years
        test_size = 48 # 48 months or 4 years

        # Split the data into train and test sets
        train_raw_total = df_adjusted[:-test_size] # This total trainning set will be used to train the final model
        df_train = train_raw_total[:-val_size]
        df_val = train_raw_total[-val_size:]
        df_test = df_adjusted[-test_size:]

        # Let´s scale the dfs

        scaler = MinMaxScaler(feature_range=(0,1))
        scaled_train = scaler.fit_transform(df_train)
        scaled_val = scaler.transform(df_val)
        scaled_test = scaler.transform(df_test)
        # include df columns names in the train and test sets
        train = pd.DataFrame(scaled_train, columns=df_train.columns)
        val = pd.DataFrame(scaled_val, columns=df_val.columns)
        test = pd.DataFrame(scaled_test, columns=df_test.columns)
        # Include the index in the train and test sets
        train.index = df_train.index
        val.index = df_val.index
        test.index = df_test.index

        # Converting the series to samples
        # We will use the past 12 months to predict the next 12 months
        def createXY(dataset, n_past, n_future):
            dataX, dataY = [], []
            # Loop for the entire dataset
            for i in range(n_past, len(dataset) - n_future + 1):
                dataX.append(dataset.iloc[i - n_past:i].values)  # Past n months
                dataY.append(dataset.iloc[i + n_future - 1, 0])  #
            return np.array(dataX), np.array(dataY)

        n_past = 12  # Number of past months to use
        n_future = 12  # Number of future months to predict

        # Create the samples
        X_train, Y_train = createXY(train, n_past, n_future)
        X_val, Y_val = createXY(val, n_past, n_future)
        X_test, Y_test = createXY(test, n_past, n_future)

        # Define EarlyStopping callback
        early_stopping = EarlyStopping(monitor='val_loss', patience=patience, restore_best_weights=True) # Stop training when the validation loss is no longer decreasing after X epochs


        # train the model
        history = best_model.fit(X_train, Y_train, 
                                 validation_data=(X_val, Y_val), 
                                 epochs=epochs, batch_size=batch_size, 
                                 verbose=2,
                                 callbacks=[early_stopping])
        # Let's predict the test set using the best model
        predictions_test_scaled = best_model.predict(X_test)

        # Let's reshape the predictions and Y_val to revert the scaling
        # Reshape predictions to 2D
        predictions_test_scaled_2d = predictions_test_scaled.reshape(-1, 1)
        # Get the last timestep of X_test
        X_test_last_timestep = X_test[:, -1, :]
        # Replace the first column of X_test_last_timestep with the scaled predictions.
        X_test_last_timestep[:, 0] = predictions_test_scaled_2d[:, 0]
        # unscale the predictions
        predictions_test_rescaled = scaler.inverse_transform(X_test_last_timestep)[:, 0]

        # Let's convert the predictions and Y_test to a dataframe usind the index from test
        predictions_test_df = pd.DataFrame(predictions_test_rescaled, index=test.index[-len(predictions_test_rescaled):], columns=[target_variable])

        # Reverse the decomposition of the time series
        #predictions = recompose_time_series(predictions_test_df, decomp_dict)
        predictions = predictions_test_df.copy()
        Y_test = df_adjusted[-len(predictions):][target_variable]

        # Calculate the error
        mape_best_RNN = mean_absolute_percentage_error(Y_test, predictions)
        rmse_best_RNN = np.sqrt(mean_squared_error(Y_test, predictions))
        mae_best_RNN = mean_absolute_error(Y_test, predictions)

        #print(f'MAPE best RNN: {mape_best_RNN}')
        #print(f'RMSE best RNN: {rmse_best_RNN}')
        #print(f'MAE best RNN: {mae_best_RNN}')

        # Armazenamento dos erros no dicionário
        errors_dict[(file_path, remove_outliers_threshold)] = {'MAPE': mape_best_RNN, 'RMSE': rmse_best_RNN, 'MAE': mae_best_RNN}

# Exibição dos resultados
for key, value in errors_dict.items():
    print(f"File: {key[0]}, Outlier Threshold: {key[1]} -> Errors: {value}")
# Out:
# g:\My Drive\Data_Projects\MDS\master_thesis\fiscal-balance-forecast\.venv\Lib\site-packages\keras\src\saving\saving_lib.py:396: UserWarning: Skipping variable loading for optimizer 'adam', because it has 12 variables whereas the saved optimizer has 2 variables.
#   trackable.load_own_variables(weights_store.get(inner_path))
# REading File: ../data/data_cleaned_LASSO.csv
# Outlier Threshold: nan
# Epoch 1/75
# 2/2 - 1s - 408ms/step - loss: 32.3761 - val_loss: 31.5074
# Epoch 2/75
# 2/2 - 0s - 26ms/step - loss: 31.5465 - val_loss: 31.4737
# Epoch 3/75
# 2/2 - 0s - 26ms/step - loss: 31.3161 - val_loss: 30.8903
# Epoch 4/75
# 2/2 - 0s - 26ms/step - loss: 30.6776 - val_loss: 30.2680
# Epoch 5/75
# 2/2 - 0s - 31ms/step - loss: 30.2077 - val_loss: 29.7851
# Epoch 6/75
# 2/2 - 0s - 26ms/step - loss: 29.7369 - val_loss: 29.3188
# Epoch 7/75
# 2/2 - 0s - 31ms/step - loss: 29.1936 - val_loss: 28.8842
# Epoch 8/75
# 2/2 - 0s - 25ms/step - loss: 28.6705 - val_loss: 28.3743
# Epoch 9/75
# 2/2 - 0s - 26ms/step - loss: 28.1609 - val_loss: 27.7843
# Epoch 10/75
# 2/2 - 0s - 24ms/step - loss: 27.5934 - val_loss: 27.2062
# Epoch 11/75
# 2/2 - 0s - 32ms/step - loss: 27.0807 - val_loss: 26.6614
# Epoch 12/75
# 2/2 - 0s - 35ms/step - loss: 26.5586 - val_loss: 26.1279
# Epoch 13/75
# 2/2 - 0s - 33ms/step - loss: 25.9826 - val_loss: 25.6135
# Epoch 14/75
# 2/2 - 0s - 34ms/step - loss: 25.4467 - val_loss: 25.0933
# Epoch 15/75
# 2/2 - 0s - 31ms/step - loss: 24.9096 - val_loss: 24.5424
# Epoch 16/75
# 2/2 - 0s - 31ms/step - loss: 24.3682 - val_loss: 23.9866
# Epoch 17/75
# 2/2 - 0s - 32ms/step - loss: 23.8341 - val_loss: 23.4369
# Epoch 18/75
# 2/2 - 0s - 27ms/step - loss: 23.2772 - val_loss: 22.8992
# Epoch 19/75
# 2/2 - 0s - 25ms/step - loss: 22.7644 - val_loss: 22.3700
# Epoch 20/75
# 2/2 - 0s - 43ms/step - loss: 22.2194 - val_loss: 21.8498
# Epoch 21/75
# 2/2 - 0s - 34ms/step - loss: 21.7023 - val_loss: 21.3326
# Epoch 22/75
# 2/2 - 0s - 42ms/step - loss: 21.1850 - val_loss: 20.8109
# Epoch 23/75
# 2/2 - 0s - 32ms/step - loss: 20.6642 - val_loss: 20.2957
# Epoch 24/75
# 2/2 - 0s - 25ms/step - loss: 20.1621 - val_loss: 19.7921
# Epoch 25/75
# 2/2 - 0s - 33ms/step - loss: 19.6535 - val_loss: 19.2952
# Epoch 26/75
# 2/2 - 0s - 31ms/step - loss: 19.1530 - val_loss: 18.8060
# Epoch 27/75
# 2/2 - 0s - 26ms/step - loss: 18.6678 - val_loss: 18.3235
# Epoch 28/75
# 2/2 - 0s - 29ms/step - loss: 18.1858 - val_loss: 17.8452
# Epoch 29/75
# 2/2 - 0s - 29ms/step - loss: 17.7117 - val_loss: 17.3722
# Epoch 30/75
# 2/2 - 0s - 29ms/step - loss: 17.2434 - val_loss: 16.9083
# Epoch 31/75
# 2/2 - 0s - 33ms/step - loss: 16.7819 - val_loss: 16.4547
# Epoch 32/75
# 2/2 - 0s - 31ms/step - loss: 16.3267 - val_loss: 16.0081
# Epoch 33/75
# 2/2 - 0s - 26ms/step - loss: 15.8889 - val_loss: 15.5649
# Epoch 34/75
# 2/2 - 0s - 26ms/step - loss: 15.4428 - val_loss: 15.1314
# Epoch 35/75
# 2/2 - 0s - 28ms/step - loss: 15.0070 - val_loss: 14.7059
# Epoch 36/75
# 2/2 - 0s - 29ms/step - loss: 14.5918 - val_loss: 14.2897
# Epoch 37/75
# 2/2 - 0s - 30ms/step - loss: 14.1765 - val_loss: 13.8820
# Epoch 38/75
# 2/2 - 0s - 25ms/step - loss: 13.7612 - val_loss: 13.4808
# Epoch 39/75
# 2/2 - 0s - 31ms/step - loss: 13.3741 - val_loss: 13.0895
# Epoch 40/75
# 2/2 - 0s - 28ms/step - loss: 12.9821 - val_loss: 12.7086
# Epoch 41/75
# 2/2 - 0s - 30ms/step - loss: 12.5978 - val_loss: 12.3313
# Epoch 42/75
# 2/2 - 0s - 25ms/step - loss: 12.2270 - val_loss: 11.9615
# Epoch 43/75
# 2/2 - 0s - 33ms/step - loss: 11.8627 - val_loss: 11.6015
# Epoch 44/75
# 2/2 - 0s - 29ms/step - loss: 11.5000 - val_loss: 11.2502
# Epoch 45/75
# 2/2 - 0s - 28ms/step - loss: 11.1446 - val_loss: 10.9069
# Epoch 46/75
# 2/2 - 0s - 27ms/step - loss: 10.8147 - val_loss: 10.5722
# Epoch 47/75
# 2/2 - 0s - 32ms/step - loss: 10.4806 - val_loss: 10.2452
# Epoch 48/75
# 2/2 - 0s - 30ms/step - loss: 10.1530 - val_loss: 9.9250
# Epoch 49/75
# 2/2 - 0s - 27ms/step - loss: 9.8419 - val_loss: 9.6126
# Epoch 50/75
# 2/2 - 0s - 30ms/step - loss: 9.5208 - val_loss: 9.3088
# Epoch 51/75
# 2/2 - 0s - 26ms/step - loss: 9.2264 - val_loss: 9.0146
# Epoch 52/75
# 2/2 - 0s - 32ms/step - loss: 8.9286 - val_loss: 8.7257
# Epoch 53/75
# 2/2 - 0s - 29ms/step - loss: 8.6426 - val_loss: 8.4443
# Epoch 54/75
# 2/2 - 0s - 27ms/step - loss: 8.3603 - val_loss: 8.1711
# Epoch 55/75
# 2/2 - 0s - 26ms/step - loss: 8.0907 - val_loss: 7.9037
# Epoch 56/75
# 2/2 - 0s - 29ms/step - loss: 7.8325 - val_loss: 7.6425
# Epoch 57/75
# 2/2 - 0s - 28ms/step - loss: 7.5723 - val_loss: 7.3888
# Epoch 58/75
# 2/2 - 0s - 25ms/step - loss: 7.3115 - val_loss: 7.1427
# Epoch 59/75
# 2/2 - 0s - 34ms/step - loss: 7.0665 - val_loss: 6.9024
# Epoch 60/75
# 2/2 - 0s - 27ms/step - loss: 6.8297 - val_loss: 6.6685
# Epoch 61/75
# 2/2 - 0s - 36ms/step - loss: 6.6001 - val_loss: 6.4413
# Epoch 62/75
# 2/2 - 0s - 39ms/step - loss: 6.3790 - val_loss: 6.2208
# Epoch 63/75
# 2/2 - 0s - 25ms/step - loss: 6.1530 - val_loss: 6.0064
# Epoch 64/75
# 2/2 - 0s - 36ms/step - loss: 5.9422 - val_loss: 5.7994
# Epoch 65/75
# 2/2 - 0s - 55ms/step - loss: 5.7362 - val_loss: 5.5970
# Epoch 66/75
# 2/2 - 0s - 31ms/step - loss: 5.5374 - val_loss: 5.4005
# Epoch 67/75
# 2/2 - 0s - 31ms/step - loss: 5.3418 - val_loss: 5.2103
# Epoch 68/75
# 2/2 - 0s - 27ms/step - loss: 5.1503 - val_loss: 5.0264
# Epoch 69/75
# 2/2 - 0s - 29ms/step - loss: 4.9775 - val_loss: 4.8492
# Epoch 70/75
# 2/2 - 0s - 29ms/step - loss: 4.7866 - val_loss: 4.6782
# Epoch 71/75
# 2/2 - 0s - 26ms/step - loss: 4.6190 - val_loss: 4.5112
# Epoch 72/75
# 2/2 - 0s - 27ms/step - loss: 4.4550 - val_loss: 4.3486
# Epoch 73/75
# 2/2 - 0s - 35ms/step - loss: 4.2938 - val_loss: 4.1918
# Epoch 74/75
# 2/2 - 0s - 27ms/step - loss: 4.1362 - val_loss: 4.0408
# Epoch 75/75
# 2/2 - 0s - 27ms/step - loss: 3.9870 - val_loss: 3.8957
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# Outlier Threshold: 0.05
# Epoch 1/75
# 2/2 - 0s - 44ms/step - loss: 3.8407 - val_loss: 3.7538
# Epoch 2/75
# 2/2 - 0s - 31ms/step - loss: 3.7008 - val_loss: 3.6163
# Epoch 3/75
# 2/2 - 0s - 33ms/step - loss: 3.5675 - val_loss: 3.4844
# Epoch 4/75
# 2/2 - 0s - 30ms/step - loss: 3.4355 - val_loss: 3.3581
# Epoch 5/75
# 2/2 - 0s - 26ms/step - loss: 3.3073 - val_loss: 3.2363
# Epoch 6/75
# 2/2 - 0s - 31ms/step - loss: 3.1860 - val_loss: 3.1167
# Epoch 7/75
# 2/2 - 0s - 28ms/step - loss: 3.0726 - val_loss: 3.0026
# Epoch 8/75
# 2/2 - 0s - 27ms/step - loss: 2.9577 - val_loss: 2.8933
# Epoch 9/75
# 2/2 - 0s - 29ms/step - loss: 2.8511 - val_loss: 2.7874
# Epoch 10/75
# 2/2 - 0s - 33ms/step - loss: 2.7471 - val_loss: 2.6844
# Epoch 11/75
# 2/2 - 0s - 27ms/step - loss: 2.6441 - val_loss: 2.5874
# Epoch 12/75
# 2/2 - 0s - 31ms/step - loss: 2.5476 - val_loss: 2.4922
# Epoch 13/75
# 2/2 - 0s - 30ms/step - loss: 2.4516 - val_loss: 2.3991
# Epoch 14/75
# 2/2 - 0s - 27ms/step - loss: 2.3567 - val_loss: 2.3096
# Epoch 15/75
# 2/2 - 0s - 40ms/step - loss: 2.2679 - val_loss: 2.2221
# Epoch 16/75
# 2/2 - 0s - 35ms/step - loss: 2.1800 - val_loss: 2.1394
# Epoch 17/75
# 2/2 - 0s - 33ms/step - loss: 2.0980 - val_loss: 2.0601
# Epoch 18/75
# 2/2 - 0s - 32ms/step - loss: 2.0223 - val_loss: 1.9840
# Epoch 19/75
# 2/2 - 0s - 33ms/step - loss: 1.9500 - val_loss: 1.9114
# Epoch 20/75
# 2/2 - 0s - 33ms/step - loss: 1.8739 - val_loss: 1.8416
# Epoch 21/75
# 2/2 - 0s - 31ms/step - loss: 1.8050 - val_loss: 1.7711
# Epoch 22/75
# 2/2 - 0s - 31ms/step - loss: 1.7369 - val_loss: 1.7059
# Epoch 23/75
# 2/2 - 0s - 57ms/step - loss: 1.6756 - val_loss: 1.6440
# Epoch 24/75
# 2/2 - 0s - 31ms/step - loss: 1.6088 - val_loss: 1.5827
# Epoch 25/75
# 2/2 - 0s - 35ms/step - loss: 1.5476 - val_loss: 1.5244
# Epoch 26/75
# 2/2 - 0s - 38ms/step - loss: 1.4950 - val_loss: 1.4705
# Epoch 27/75
# 2/2 - 0s - 33ms/step - loss: 1.4353 - val_loss: 1.4168
# Epoch 28/75
# 2/2 - 0s - 37ms/step - loss: 1.3811 - val_loss: 1.3639
# Epoch 29/75
# 2/2 - 0s - 34ms/step - loss: 1.3298 - val_loss: 1.3146
# Epoch 30/75
# 2/2 - 0s - 33ms/step - loss: 1.2841 - val_loss: 1.2675
# Epoch 31/75
# 2/2 - 0s - 35ms/step - loss: 1.2380 - val_loss: 1.2225
# Epoch 32/75
# 2/2 - 0s - 30ms/step - loss: 1.1898 - val_loss: 1.1778
# Epoch 33/75
# 2/2 - 0s - 27ms/step - loss: 1.1480 - val_loss: 1.1341
# Epoch 34/75
# 2/2 - 0s - 27ms/step - loss: 1.1056 - val_loss: 1.0931
# Epoch 35/75
# 2/2 - 0s - 30ms/step - loss: 1.0675 - val_loss: 1.0551
# Epoch 36/75
# 2/2 - 0s - 28ms/step - loss: 1.0282 - val_loss: 1.0170
# Epoch 37/75
# 2/2 - 0s - 28ms/step - loss: 0.9908 - val_loss: 0.9804
# Epoch 38/75
# 2/2 - 0s - 27ms/step - loss: 0.9577 - val_loss: 0.9458
# Epoch 39/75
# 2/2 - 0s - 29ms/step - loss: 0.9248 - val_loss: 0.9133
# Epoch 40/75
# 2/2 - 0s - 32ms/step - loss: 0.8893 - val_loss: 0.8817
# Epoch 41/75
# 2/2 - 0s - 29ms/step - loss: 0.8617 - val_loss: 0.8517
# Epoch 42/75
# 2/2 - 0s - 36ms/step - loss: 0.8272 - val_loss: 0.8222
# Epoch 43/75
# 2/2 - 0s - 31ms/step - loss: 0.7997 - val_loss: 0.7945
# Epoch 44/75
# 2/2 - 0s - 33ms/step - loss: 0.7697 - val_loss: 0.7672
# Epoch 45/75
# 2/2 - 0s - 43ms/step - loss: 0.7455 - val_loss: 0.7413
# Epoch 46/75
# 2/2 - 0s - 31ms/step - loss: 0.7179 - val_loss: 0.7168
# Epoch 47/75
# 2/2 - 0s - 25ms/step - loss: 0.6924 - val_loss: 0.6935
# Epoch 48/75
# 2/2 - 0s - 33ms/step - loss: 0.6675 - val_loss: 0.6711
# Epoch 49/75
# 2/2 - 0s - 32ms/step - loss: 0.6461 - val_loss: 0.6491
# Epoch 50/75
# 2/2 - 0s - 26ms/step - loss: 0.6255 - val_loss: 0.6289
# Epoch 51/75
# 2/2 - 0s - 32ms/step - loss: 0.6072 - val_loss: 0.6096
# Epoch 52/75
# 2/2 - 0s - 29ms/step - loss: 0.5831 - val_loss: 0.5905
# Epoch 53/75
# 2/2 - 0s - 33ms/step - loss: 0.5637 - val_loss: 0.5723
# Epoch 54/75
# 2/2 - 0s - 38ms/step - loss: 0.5507 - val_loss: 0.5546
# Epoch 55/75
# 2/2 - 0s - 31ms/step - loss: 0.5307 - val_loss: 0.5381
# Epoch 56/75
# 2/2 - 0s - 32ms/step - loss: 0.5142 - val_loss: 0.5219
# Epoch 57/75
# 2/2 - 0s - 30ms/step - loss: 0.4960 - val_loss: 0.5070
# Epoch 58/75
# 2/2 - 0s - 35ms/step - loss: 0.4818 - val_loss: 0.4927
# Epoch 59/75
# 2/2 - 0s - 29ms/step - loss: 0.4682 - val_loss: 0.4781
# Epoch 60/75
# 2/2 - 0s - 34ms/step - loss: 0.4509 - val_loss: 0.4651
# Epoch 61/75
# 2/2 - 0s - 29ms/step - loss: 0.4443 - val_loss: 0.4521
# Epoch 62/75
# 2/2 - 0s - 28ms/step - loss: 0.4282 - val_loss: 0.4398
# Epoch 63/75
# 2/2 - 0s - 26ms/step - loss: 0.4159 - val_loss: 0.4281
# Epoch 64/75
# 2/2 - 0s - 33ms/step - loss: 0.4038 - val_loss: 0.4170
# Epoch 65/75
# 2/2 - 0s - 30ms/step - loss: 0.3905 - val_loss: 0.4061
# Epoch 66/75
# 2/2 - 0s - 29ms/step - loss: 0.3854 - val_loss: 0.3956
# Epoch 67/75
# 2/2 - 0s - 32ms/step - loss: 0.3731 - val_loss: 0.3851
# Epoch 68/75
# 2/2 - 0s - 24ms/step - loss: 0.3577 - val_loss: 0.3756
# Epoch 69/75
# 2/2 - 0s - 29ms/step - loss: 0.3529 - val_loss: 0.3674
# Epoch 70/75
# 2/2 - 0s - 28ms/step - loss: 0.3402 - val_loss: 0.3580
# Epoch 71/75
# 2/2 - 0s - 58ms/step - loss: 0.3316 - val_loss: 0.3488
# Epoch 72/75
# 2/2 - 0s - 33ms/step - loss: 0.3218 - val_loss: 0.3400
# Epoch 73/75
# 2/2 - 0s - 30ms/step - loss: 0.3145 - val_loss: 0.3331
# Epoch 74/75
# 2/2 - 0s - 30ms/step - loss: 0.3065 - val_loss: 0.3250
# Epoch 75/75
# 2/2 - 0s - 29ms/step - loss: 0.3000 - val_loss: 0.3177
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Outlier Threshold: 0.1
# Epoch 1/75
# 2/2 - 0s - 43ms/step - loss: 0.2934 - val_loss: 0.3122
# Epoch 2/75
# 2/2 - 0s - 31ms/step - loss: 0.2838 - val_loss: 0.3062
# Epoch 3/75
# 2/2 - 0s - 35ms/step - loss: 0.2830 - val_loss: 0.3004
# Epoch 4/75
# 2/2 - 0s - 31ms/step - loss: 0.2717 - val_loss: 0.2928
# Epoch 5/75
# 2/2 - 0s - 29ms/step - loss: 0.2677 - val_loss: 0.2865
# Epoch 6/75
# 2/2 - 0s - 30ms/step - loss: 0.2592 - val_loss: 0.2806
# Epoch 7/75
# 2/2 - 0s - 32ms/step - loss: 0.2537 - val_loss: 0.2763
# Epoch 8/75
# 2/2 - 0s - 34ms/step - loss: 0.2495 - val_loss: 0.2703
# Epoch 9/75
# 2/2 - 0s - 30ms/step - loss: 0.2412 - val_loss: 0.2645
# Epoch 10/75
# 2/2 - 0s - 33ms/step - loss: 0.2370 - val_loss: 0.2607
# Epoch 11/75
# 2/2 - 0s - 33ms/step - loss: 0.2307 - val_loss: 0.2567
# Epoch 12/75
# 2/2 - 0s - 25ms/step - loss: 0.2259 - val_loss: 0.2521
# Epoch 13/75
# 2/2 - 0s - 37ms/step - loss: 0.2236 - val_loss: 0.2472
# Epoch 14/75
# 2/2 - 0s - 30ms/step - loss: 0.2160 - val_loss: 0.2430
# Epoch 15/75
# 2/2 - 0s - 35ms/step - loss: 0.2139 - val_loss: 0.2389
# Epoch 16/75
# 2/2 - 0s - 31ms/step - loss: 0.2146 - val_loss: 0.2353
# Epoch 17/75
# 2/2 - 0s - 32ms/step - loss: 0.2104 - val_loss: 0.2317
# Epoch 18/75
# 2/2 - 0s - 32ms/step - loss: 0.2037 - val_loss: 0.2265
# Epoch 19/75
# 2/2 - 0s - 31ms/step - loss: 0.1956 - val_loss: 0.2243
# Epoch 20/75
# 2/2 - 0s - 24ms/step - loss: 0.1973 - val_loss: 0.2218
# Epoch 21/75
# 2/2 - 0s - 33ms/step - loss: 0.1939 - val_loss: 0.2155
# Epoch 22/75
# 2/2 - 0s - 33ms/step - loss: 0.1857 - val_loss: 0.2137
# Epoch 23/75
# 2/2 - 0s - 37ms/step - loss: 0.1903 - val_loss: 0.2152
# Epoch 24/75
# 2/2 - 0s - 27ms/step - loss: 0.1831 - val_loss: 0.2094
# Epoch 25/75
# 2/2 - 0s - 30ms/step - loss: 0.1788 - val_loss: 0.2036
# Epoch 26/75
# 2/2 - 0s - 28ms/step - loss: 0.1751 - val_loss: 0.2016
# Epoch 27/75
# 2/2 - 0s - 31ms/step - loss: 0.1734 - val_loss: 0.2021
# Epoch 28/75
# 2/2 - 0s - 27ms/step - loss: 0.1717 - val_loss: 0.1977
# Epoch 29/75
# 2/2 - 0s - 30ms/step - loss: 0.1657 - val_loss: 0.1944
# Epoch 30/75
# 2/2 - 0s - 28ms/step - loss: 0.1636 - val_loss: 0.1944
# Epoch 31/75
# 2/2 - 0s - 32ms/step - loss: 0.1623 - val_loss: 0.1921
# Epoch 32/75
# 2/2 - 0s - 27ms/step - loss: 0.1569 - val_loss: 0.1878
# Epoch 33/75
# 2/2 - 0s - 28ms/step - loss: 0.1586 - val_loss: 0.1854
# Epoch 34/75
# 2/2 - 0s - 34ms/step - loss: 0.1554 - val_loss: 0.1834
# Epoch 35/75
# 2/2 - 0s - 33ms/step - loss: 0.1572 - val_loss: 0.1807
# Epoch 36/75
# 2/2 - 0s - 28ms/step - loss: 0.1510 - val_loss: 0.1791
# Epoch 37/75
# 2/2 - 0s - 27ms/step - loss: 0.1493 - val_loss: 0.1795
# Epoch 38/75
# 2/2 - 0s - 25ms/step - loss: 0.1495 - val_loss: 0.1766
# Epoch 39/75
# 2/2 - 0s - 29ms/step - loss: 0.1473 - val_loss: 0.1732
# Epoch 40/75
# 2/2 - 0s - 27ms/step - loss: 0.1427 - val_loss: 0.1718
# Epoch 41/75
# 2/2 - 0s - 27ms/step - loss: 0.1494 - val_loss: 0.1701
# Epoch 42/75
# 2/2 - 0s - 26ms/step - loss: 0.1411 - val_loss: 0.1701
# Epoch 43/75
# 2/2 - 0s - 29ms/step - loss: 0.1443 - val_loss: 0.1718
# Epoch 44/75
# 2/2 - 0s - 29ms/step - loss: 0.1391 - val_loss: 0.1696
# Epoch 45/75
# 2/2 - 0s - 29ms/step - loss: 0.1349 - val_loss: 0.1651
# Epoch 46/75
# 2/2 - 0s - 28ms/step - loss: 0.1399 - val_loss: 0.1641
# Epoch 47/75
# 2/2 - 0s - 28ms/step - loss: 0.1322 - val_loss: 0.1635
# Epoch 48/75
# 2/2 - 0s - 31ms/step - loss: 0.1335 - val_loss: 0.1633
# Epoch 49/75
# 2/2 - 0s - 28ms/step - loss: 0.1326 - val_loss: 0.1624
# Epoch 50/75
# 2/2 - 0s - 28ms/step - loss: 0.1337 - val_loss: 0.1608
# Epoch 51/75
# 2/2 - 0s - 27ms/step - loss: 0.1302 - val_loss: 0.1610
# Epoch 52/75
# 2/2 - 0s - 30ms/step - loss: 0.1318 - val_loss: 0.1601
# Epoch 53/75
# 2/2 - 0s - 26ms/step - loss: 0.1291 - val_loss: 0.1604
# Epoch 54/75
# 2/2 - 0s - 30ms/step - loss: 0.1263 - val_loss: 0.1563
# Epoch 55/75
# 2/2 - 0s - 29ms/step - loss: 0.1299 - val_loss: 0.1543
# Epoch 56/75
# 2/2 - 0s - 29ms/step - loss: 0.1250 - val_loss: 0.1548
# Epoch 57/75
# 2/2 - 0s - 28ms/step - loss: 0.1236 - val_loss: 0.1523
# Epoch 58/75
# 2/2 - 0s - 29ms/step - loss: 0.1238 - val_loss: 0.1517
# Epoch 59/75
# 2/2 - 0s - 27ms/step - loss: 0.1230 - val_loss: 0.1525
# Epoch 60/75
# 2/2 - 0s - 27ms/step - loss: 0.1205 - val_loss: 0.1514
# Epoch 61/75
# 2/2 - 0s - 31ms/step - loss: 0.1203 - val_loss: 0.1495
# Epoch 62/75
# 2/2 - 0s - 28ms/step - loss: 0.1177 - val_loss: 0.1495
# Epoch 63/75
# 2/2 - 0s - 31ms/step - loss: 0.1182 - val_loss: 0.1489
# Epoch 64/75
# 2/2 - 0s - 26ms/step - loss: 0.1191 - val_loss: 0.1458
# Epoch 65/75
# 2/2 - 0s - 22ms/step - loss: 0.1198 - val_loss: 0.1454
# Epoch 66/75
# 2/2 - 0s - 27ms/step - loss: 0.1137 - val_loss: 0.1469
# Epoch 67/75
# 2/2 - 0s - 26ms/step - loss: 0.1122 - val_loss: 0.1474
# Epoch 68/75
# 2/2 - 0s - 27ms/step - loss: 0.1169 - val_loss: 0.1434
# Epoch 69/75
# 2/2 - 0s - 29ms/step - loss: 0.1117 - val_loss: 0.1438
# Epoch 70/75
# 2/2 - 0s - 28ms/step - loss: 0.1120 - val_loss: 0.1459
# Epoch 71/75
# 2/2 - 0s - 27ms/step - loss: 0.1125 - val_loss: 0.1424
# Epoch 72/75
# 2/2 - 0s - 28ms/step - loss: 0.1141 - val_loss: 0.1405
# Epoch 73/75
# 2/2 - 0s - 27ms/step - loss: 0.1105 - val_loss: 0.1410
# Epoch 74/75
# 2/2 - 0s - 29ms/step - loss: 0.1159 - val_loss: 0.1412
# Epoch 75/75
# 2/2 - 0s - 29ms/step - loss: 0.1102 - val_loss: 0.1409
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Outlier Threshold: 0.15
# Epoch 1/75
# 2/2 - 0s - 34ms/step - loss: 0.1109 - val_loss: 0.1459
# Epoch 2/75
# 2/2 - 0s - 34ms/step - loss: 0.1120 - val_loss: 0.1457
# Epoch 3/75
# 2/2 - 0s - 29ms/step - loss: 0.1134 - val_loss: 0.1446
# Epoch 4/75
# 2/2 - 0s - 31ms/step - loss: 0.1170 - val_loss: 0.1404
# Epoch 5/75
# 2/2 - 0s - 30ms/step - loss: 0.1118 - val_loss: 0.1421
# Epoch 6/75
# 2/2 - 0s - 29ms/step - loss: 0.1116 - val_loss: 0.1385
# Epoch 7/75
# 2/2 - 0s - 30ms/step - loss: 0.1120 - val_loss: 0.1430
# Epoch 8/75
# 2/2 - 0s - 32ms/step - loss: 0.1100 - val_loss: 0.1410
# Epoch 9/75
# 2/2 - 0s - 33ms/step - loss: 0.1133 - val_loss: 0.1378
# Epoch 10/75
# 2/2 - 0s - 28ms/step - loss: 0.1083 - val_loss: 0.1349
# Epoch 11/75
# 2/2 - 0s - 28ms/step - loss: 0.1075 - val_loss: 0.1370
# Epoch 12/75
# 2/2 - 0s - 25ms/step - loss: 0.1094 - val_loss: 0.1338
# Epoch 13/75
# 2/2 - 0s - 34ms/step - loss: 0.1076 - val_loss: 0.1329
# Epoch 14/75
# 2/2 - 0s - 35ms/step - loss: 0.1086 - val_loss: 0.1355
# Epoch 15/75
# 2/2 - 0s - 27ms/step - loss: 0.1057 - val_loss: 0.1336
# Epoch 16/75
# 2/2 - 0s - 29ms/step - loss: 0.1057 - val_loss: 0.1335
# Epoch 17/75
# 2/2 - 0s - 30ms/step - loss: 0.1037 - val_loss: 0.1337
# Epoch 18/75
# 2/2 - 0s - 25ms/step - loss: 0.1032 - val_loss: 0.1319
# Epoch 19/75
# 2/2 - 0s - 33ms/step - loss: 0.1004 - val_loss: 0.1328
# Epoch 20/75
# 2/2 - 0s - 49ms/step - loss: 0.1038 - val_loss: 0.1299
# Epoch 21/75
# 2/2 - 0s - 27ms/step - loss: 0.1127 - val_loss: 0.1309
# Epoch 22/75
# 2/2 - 0s - 31ms/step - loss: 0.1086 - val_loss: 0.1309
# Epoch 23/75
# 2/2 - 0s - 27ms/step - loss: 0.1099 - val_loss: 0.1324
# Epoch 24/75
# 2/2 - 0s - 31ms/step - loss: 0.1049 - val_loss: 0.1297
# Epoch 25/75
# 2/2 - 0s - 28ms/step - loss: 0.1035 - val_loss: 0.1275
# Epoch 26/75
# 2/2 - 0s - 26ms/step - loss: 0.1083 - val_loss: 0.1276
# Epoch 27/75
# 2/2 - 0s - 28ms/step - loss: 0.0997 - val_loss: 0.1313
# Epoch 28/75
# 2/2 - 0s - 29ms/step - loss: 0.0995 - val_loss: 0.1256
# Epoch 29/75
# 2/2 - 0s - 28ms/step - loss: 0.1000 - val_loss: 0.1248
# Epoch 30/75
# 2/2 - 0s - 26ms/step - loss: 0.0983 - val_loss: 0.1259
# Epoch 31/75
# 2/2 - 0s - 27ms/step - loss: 0.1010 - val_loss: 0.1263
# Epoch 32/75
# 2/2 - 0s - 30ms/step - loss: 0.1000 - val_loss: 0.1239
# Epoch 33/75
# 2/2 - 0s - 24ms/step - loss: 0.0976 - val_loss: 0.1261
# Epoch 34/75
# 2/2 - 0s - 26ms/step - loss: 0.0971 - val_loss: 0.1277
# Epoch 35/75
# 2/2 - 0s - 26ms/step - loss: 0.0979 - val_loss: 0.1246
# Epoch 36/75
# 2/2 - 0s - 30ms/step - loss: 0.0959 - val_loss: 0.1233
# Epoch 37/75
# 2/2 - 0s - 29ms/step - loss: 0.0998 - val_loss: 0.1254
# Epoch 38/75
# 2/2 - 0s - 35ms/step - loss: 0.0980 - val_loss: 0.1228
# Epoch 39/75
# 2/2 - 0s - 28ms/step - loss: 0.0996 - val_loss: 0.1260
# Epoch 40/75
# 2/2 - 0s - 26ms/step - loss: 0.1020 - val_loss: 0.1213
# Epoch 41/75
# 2/2 - 0s - 27ms/step - loss: 0.0974 - val_loss: 0.1220
# Epoch 42/75
# 2/2 - 0s - 27ms/step - loss: 0.1016 - val_loss: 0.1194
# Epoch 43/75
# 2/2 - 0s - 26ms/step - loss: 0.0956 - val_loss: 0.1198
# Epoch 44/75
# 2/2 - 0s - 27ms/step - loss: 0.1025 - val_loss: 0.1208
# Epoch 45/75
# 2/2 - 0s - 26ms/step - loss: 0.0964 - val_loss: 0.1201
# Epoch 46/75
# 2/2 - 0s - 28ms/step - loss: 0.0958 - val_loss: 0.1188
# Epoch 47/75
# 2/2 - 0s - 31ms/step - loss: 0.0980 - val_loss: 0.1199
# Epoch 48/75
# 2/2 - 0s - 35ms/step - loss: 0.0978 - val_loss: 0.1200
# Epoch 49/75
# 2/2 - 0s - 31ms/step - loss: 0.0967 - val_loss: 0.1188
# Epoch 50/75
# 2/2 - 0s - 30ms/step - loss: 0.0944 - val_loss: 0.1176
# Epoch 51/75
# 2/2 - 0s - 30ms/step - loss: 0.0934 - val_loss: 0.1200
# Epoch 52/75
# 2/2 - 0s - 31ms/step - loss: 0.0945 - val_loss: 0.1179
# Epoch 53/75
# 2/2 - 0s - 29ms/step - loss: 0.0921 - val_loss: 0.1160
# Epoch 54/75
# 2/2 - 0s - 28ms/step - loss: 0.0966 - val_loss: 0.1165
# Epoch 55/75
# 2/2 - 0s - 29ms/step - loss: 0.0921 - val_loss: 0.1181
# Epoch 56/75
# 2/2 - 0s - 29ms/step - loss: 0.0933 - val_loss: 0.1156
# Epoch 57/75
# 2/2 - 0s - 25ms/step - loss: 0.0922 - val_loss: 0.1161
# Epoch 58/75
# 2/2 - 0s - 25ms/step - loss: 0.0931 - val_loss: 0.1141
# Epoch 59/75
# 2/2 - 0s - 26ms/step - loss: 0.0928 - val_loss: 0.1161
# Epoch 60/75
# 2/2 - 0s - 34ms/step - loss: 0.0923 - val_loss: 0.1163
# Epoch 61/75
# 2/2 - 0s - 29ms/step - loss: 0.0899 - val_loss: 0.1159
# Epoch 62/75
# 2/2 - 0s - 30ms/step - loss: 0.0913 - val_loss: 0.1137
# Epoch 63/75
# 2/2 - 0s - 21ms/step - loss: 0.0910 - val_loss: 0.1141
# Epoch 64/75
# 2/2 - 0s - 34ms/step - loss: 0.0904 - val_loss: 0.1137
# Epoch 65/75
# 2/2 - 0s - 31ms/step - loss: 0.0952 - val_loss: 0.1140
# Epoch 66/75
# 2/2 - 0s - 25ms/step - loss: 0.0907 - val_loss: 0.1138
# Epoch 67/75
# 2/2 - 0s - 29ms/step - loss: 0.0898 - val_loss: 0.1150
# Epoch 68/75
# 2/2 - 0s - 26ms/step - loss: 0.0986 - val_loss: 0.1135
# Epoch 69/75
# 2/2 - 0s - 27ms/step - loss: 0.0895 - val_loss: 0.1124
# Epoch 70/75
# 2/2 - 0s - 26ms/step - loss: 0.0915 - val_loss: 0.1122
# Epoch 71/75
# 2/2 - 0s - 26ms/step - loss: 0.0961 - val_loss: 0.1135
# Epoch 72/75
# 2/2 - 0s - 30ms/step - loss: 0.0877 - val_loss: 0.1120
# Epoch 73/75
# 2/2 - 0s - 30ms/step - loss: 0.0928 - val_loss: 0.1118
# Epoch 74/75
# 2/2 - 0s - 27ms/step - loss: 0.0882 - val_loss: 0.1100
# Epoch 75/75
# 2/2 - 0s - 26ms/step - loss: 0.0915 - val_loss: 0.1110
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Outlier Threshold: 0.2
# Epoch 1/75
# 2/2 - 0s - 40ms/step - loss: 0.1208 - val_loss: 0.2096
# Epoch 2/75
# 2/2 - 0s - 26ms/step - loss: 0.1250 - val_loss: 0.2023
# Epoch 3/75
# 2/2 - 0s - 30ms/step - loss: 0.1234 - val_loss: 0.2060
# Epoch 4/75
# 2/2 - 0s - 31ms/step - loss: 0.1113 - val_loss: 0.2256
# Epoch 5/75
# 2/2 - 0s - 27ms/step - loss: 0.1196 - val_loss: 0.2001
# Epoch 6/75
# 2/2 - 0s - 27ms/step - loss: 0.1137 - val_loss: 0.1908
# Epoch 7/75
# 2/2 - 0s - 29ms/step - loss: 0.1137 - val_loss: 0.2140
# Epoch 8/75
# 2/2 - 0s - 27ms/step - loss: 0.1069 - val_loss: 0.2120
# Epoch 9/75
# 2/2 - 0s - 25ms/step - loss: 0.1014 - val_loss: 0.1881
# Epoch 10/75
# 2/2 - 0s - 26ms/step - loss: 0.1055 - val_loss: 0.1898
# Epoch 11/75
# 2/2 - 0s - 26ms/step - loss: 0.0966 - val_loss: 0.2202
# Epoch 12/75
# 2/2 - 0s - 21ms/step - loss: 0.1127 - val_loss: 0.2021
# Epoch 13/75
# 2/2 - 0s - 32ms/step - loss: 0.0928 - val_loss: 0.1887
# Epoch 14/75
# 2/2 - 0s - 29ms/step - loss: 0.0981 - val_loss: 0.1918
# Epoch 15/75
# 2/2 - 0s - 29ms/step - loss: 0.0998 - val_loss: 0.1964
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# File: ../data/data_cleaned_LASSO.csv, Outlier Threshold: nan -> Errors: {'MAPE': 1.2320473, 'RMSE': 50846.7, 'MAE': 38909.207}
# File: ../data/data_cleaned_LASSO.csv, Outlier Threshold: 0.05 -> Errors: {'MAPE': 1.1181465, 'RMSE': 43593.84, 'MAE': 33909.953}
# File: ../data/data_cleaned_LASSO.csv, Outlier Threshold: 0.1 -> Errors: {'MAPE': 3.8761685, 'RMSE': 26224.848, 'MAE': 22626.865}
# File: ../data/data_cleaned_LASSO.csv, Outlier Threshold: 0.15 -> Errors: {'MAPE': 3.3037739, 'RMSE': 24961.42, 'MAE': 21776.828}
# File: ../data/data_cleaned_LASSO.csv, Outlier Threshold: 0.2 -> Errors: {'MAPE': 1.3807606, 'RMSE': 21849.766, 'MAE': 19136.52}

# %%
print(errors_dict)
# Out:
# {('../data/data_cleaned_LASSO.csv', nan): {'MAPE': 1.2320473, 'RMSE': 50846.7, 'MAE': 38909.207}, ('../data/data_cleaned_LASSO.csv', 0.05): {'MAPE': 1.1181465, 'RMSE': 43593.84, 'MAE': 33909.953}, ('../data/data_cleaned_LASSO.csv', 0.1): {'MAPE': 3.8761685, 'RMSE': 26224.848, 'MAE': 22626.865}, ('../data/data_cleaned_LASSO.csv', 0.15): {'MAPE': 3.3037739, 'RMSE': 24961.42, 'MAE': 21776.828}, ('../data/data_cleaned_LASSO.csv', 0.2): {'MAPE': 1.3807606, 'RMSE': 21849.766, 'MAE': 19136.52}}
