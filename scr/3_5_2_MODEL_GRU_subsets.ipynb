# %%
import pandas as pd
import numpy as np
import useful_functions as uf
import random as python_random
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from tensorflow.random import set_seed
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import GRU, Dense, Dropout, Input
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras.regularizers import l1_l2

# Possible datasets to test
file_paths = [
    #'../data/data_orig_parameters.csv'
    # '../data/BR_param_EDA.csv',
    #'../data/data_cleaned_RF.csv',
    '../data/data_cleaned_LASSO.csv',
    #'../data/data_cleaned_RFE.csv'
]

# List of outlier thresholds to test
outlier_thresholds = [np.nan, 0.05, 0.10, 0.15, 0.20]
#outlier_thresholds = [0.20]

# Dictionary to store the errors
errors_dict = {}

# Load the model from the file
best_model = load_model('models_parameters/best_gru_model_grid_lasso_10.keras')
# from manual hyperparameter tuning
epochs = 75
batch_size = 32
patience = 10

# Let´s define the seed for reproducibility

def func_set_seed(seed=42):
    np.random.seed(seed)
    python_random.seed(seed)
    set_seed(seed) #tensorflow.random.set_seed(seed)

# Call the function to set the seed
func_set_seed(42)

# Loop through the files and outlier thresholds
for file_path in file_paths:
    print(f"REading File: {file_path}")
    for remove_outliers_threshold in outlier_thresholds:
        print(f"Outlier Threshold: {remove_outliers_threshold}")
        # Load  data
        df_raw = pd.read_csv(file_path, parse_dates=['Date'], index_col='Date')
        target_variable = df_raw.columns[0]
        # Convert all columns to float
        df_raw = df_raw.astype('float64')   
        df = df_raw.copy()

        # Remove outliers using the threshold
        if not pd.isna(remove_outliers_threshold):
            df_cleaned = uf.remove_outliers(df.copy(), threshold=remove_outliers_threshold)
        else:
            df_cleaned = df.copy()

        # Fill missing values
        df_adjusted = uf.fill_missing_values(df_cleaned)

        # Define test, train and validation set sizes
        val_size = 48 # 48 months or 4 years
        test_size = 48 # 48 months or 4 years

        # Split the data into train and test sets
        train_raw_total = df_adjusted[:-test_size] # This total trainning set will be used to train the final model
        df_train = train_raw_total[:-val_size]
        df_val = train_raw_total[-val_size:]
        df_test = df_adjusted[-test_size:]

        # Let´s scale the dfs

        scaler = MinMaxScaler(feature_range=(0,1))
        scaled_train = scaler.fit_transform(df_train)
        scaled_val = scaler.transform(df_val)
        scaled_test = scaler.transform(df_test)
        # include df columns names in the train and test sets
        train = pd.DataFrame(scaled_train, columns=df_train.columns)
        val = pd.DataFrame(scaled_val, columns=df_val.columns)
        test = pd.DataFrame(scaled_test, columns=df_test.columns)
        # Include the index in the train and test sets
        train.index = df_train.index
        val.index = df_val.index
        test.index = df_test.index

        # Converting the series to samples
        # We will use the past 12 months to predict the next 12 months
        def createXY(dataset, n_past, n_future):
            dataX, dataY = [], []
            # Loop for the entire dataset
            for i in range(n_past, len(dataset) - n_future + 1):
                dataX.append(dataset.iloc[i - n_past:i].values)  # Past n months
                dataY.append(dataset.iloc[i + n_future - 1, 0])  #
            return np.array(dataX), np.array(dataY)

        n_past = 12  # Number of past months to use
        n_future = 12  # Number of future months to predict

        # Create the samples
        X_train, Y_train = createXY(train, n_past, n_future)
        X_val, Y_val = createXY(val, n_past, n_future)
        X_test, Y_test = createXY(test, n_past, n_future)

        # Define EarlyStopping callback
        early_stopping = EarlyStopping(monitor='val_loss', patience=patience, restore_best_weights=True) # Stoppatience=patience, restore_best_weights training when the validation loss is no longer decreasing after X epochs


        # train the model
        history = best_model.fit(X_train, Y_train, 
                                 validation_data=(X_val, Y_val), 
                                 epochs=epochs, batch_size=batch_size, 
                                 verbose=2,
                                 callbacks=[early_stopping])
        # Let's predict the test set using the best model
        predictions_test_scaled = best_model.predict(X_test)

        # Let's reshape the predictions and Y_val to revert the scaling
        # Reshape predictions to 2D
        predictions_test_scaled_2d = predictions_test_scaled.reshape(-1, 1)
        # Get the last timestep of X_test
        X_test_last_timestep = X_test[:, -1, :]
        # Replace the first column of X_test_last_timestep with the scaled predictions.
        X_test_last_timestep[:, 0] = predictions_test_scaled_2d[:, 0]
        # unscale the predictions
        predictions_test_rescaled = scaler.inverse_transform(X_test_last_timestep)[:, 0]

        # Let's convert the predictions and Y_test to a dataframe usind the index from test
        predictions_test_df = pd.DataFrame(predictions_test_rescaled, index=test.index[-len(predictions_test_rescaled):], columns=[target_variable])

        # Reverse the decomposition of the time series
        #predictions = recompose_time_series(predictions_test_df, decomp_dict)
        predictions = predictions_test_df.copy()
        Y_test = df_adjusted[-len(predictions):][target_variable]

        # Calculate the error
        mape_best_GRU = mean_absolute_percentage_error(Y_test, predictions)
        rmse_best_GRU = np.sqrt(mean_squared_error(Y_test, predictions))
        mae_best_GRU = mean_absolute_error(Y_test, predictions)

        #print(f'MAPE best GRU: {mape_best_GRU}')
        #print(f'RMSE best GRU: {rmse_best_GRU}')
        #print(f'MAE best GRU: {mae_best_GRU}')

        # Armazenamento dos erros no dicionário
        errors_dict[(file_path, remove_outliers_threshold)] = {'MAPE': mape_best_GRU, 'RMSE': rmse_best_GRU, 'MAE': mae_best_GRU}

# Exibição dos resultados
for key, value in errors_dict.items():
    print(f"File: {key[0]}, Outlier Threshold: {key[1]} -> Errors: {value}")
# Out:
# REading File: ../data/data_cleaned_LASSO.csv
# Outlier Threshold: nan
# Epoch 1/75
# 5/5 - 2s - 327ms/step - loss: 0.3660 - val_loss: 0.0932
# Epoch 2/75
# 5/5 - 0s - 25ms/step - loss: 0.0234 - val_loss: 0.0517
# Epoch 3/75
# 5/5 - 0s - 19ms/step - loss: 0.0240 - val_loss: 0.0549
# Epoch 4/75
# 5/5 - 0s - 16ms/step - loss: 0.0256 - val_loss: 0.0735
# Epoch 5/75
# 5/5 - 0s - 21ms/step - loss: 0.0782 - val_loss: 0.0877
# Epoch 6/75
# 5/5 - 0s - 19ms/step - loss: 0.0398 - val_loss: 0.0699
# Epoch 7/75
# 5/5 - 0s - 20ms/step - loss: 0.0470 - val_loss: 0.0515
# Epoch 8/75
# 5/5 - 0s - 35ms/step - loss: 0.0171 - val_loss: 0.0436
# Epoch 9/75
# 5/5 - 0s - 20ms/step - loss: 0.0194 - val_loss: 0.1514
# Epoch 10/75
# 5/5 - 0s - 22ms/step - loss: 0.0854 - val_loss: 0.0413
# Epoch 11/75
# 5/5 - 0s - 19ms/step - loss: 0.0160 - val_loss: 0.0480
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step
# Outlier Threshold: 0.05
# Epoch 1/75
# 5/5 - 0s - 49ms/step - loss: 0.0152 - val_loss: 0.0579
# Epoch 2/75
# 5/5 - 0s - 18ms/step - loss: 0.0172 - val_loss: 0.0254
# Epoch 3/75
# 5/5 - 0s - 22ms/step - loss: 0.0090 - val_loss: 0.0257
# Epoch 4/75
# 5/5 - 0s - 33ms/step - loss: 0.0096 - val_loss: 0.0183
# Epoch 5/75
# 5/5 - 0s - 25ms/step - loss: 0.0074 - val_loss: 0.0411
# Epoch 6/75
# 5/5 - 0s - 20ms/step - loss: 0.0177 - val_loss: 0.0173
# Epoch 7/75
# 5/5 - 0s - 17ms/step - loss: 0.0069 - val_loss: 0.0209
# Epoch 8/75
# 5/5 - 0s - 32ms/step - loss: 0.0095 - val_loss: 0.0179
# Epoch 9/75
# 5/5 - 0s - 18ms/step - loss: 0.0067 - val_loss: 0.0205
# Epoch 10/75
# 5/5 - 0s - 20ms/step - loss: 0.0102 - val_loss: 0.0159
# Epoch 11/75
# 5/5 - 0s - 32ms/step - loss: 0.0131 - val_loss: 0.0415
# Epoch 12/75
# 5/5 - 0s - 33ms/step - loss: 0.0107 - val_loss: 0.0284
# Epoch 13/75
# 5/5 - 0s - 33ms/step - loss: 0.0100 - val_loss: 0.0206
# Epoch 14/75
# 5/5 - 0s - 34ms/step - loss: 0.0084 - val_loss: 0.0178
# Epoch 15/75
# 5/5 - 0s - 20ms/step - loss: 0.0094 - val_loss: 0.0475
# Epoch 16/75
# 5/5 - 0s - 21ms/step - loss: 0.0131 - val_loss: 0.0223
# Epoch 17/75
# 5/5 - 0s - 19ms/step - loss: 0.0077 - val_loss: 0.0192
# Epoch 18/75
# 5/5 - 0s - 18ms/step - loss: 0.0068 - val_loss: 0.0162
# Epoch 19/75
# 5/5 - 0s - 18ms/step - loss: 0.0142 - val_loss: 0.0472
# Epoch 20/75
# 5/5 - 0s - 17ms/step - loss: 0.0109 - val_loss: 0.0258
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Outlier Threshold: 0.1
# Epoch 1/75
# 5/5 - 0s - 23ms/step - loss: 0.0091 - val_loss: 0.0411
# Epoch 2/75
# 5/5 - 0s - 20ms/step - loss: 0.0133 - val_loss: 0.0219
# Epoch 3/75
# 5/5 - 0s - 20ms/step - loss: 0.0071 - val_loss: 0.0227
# Epoch 4/75
# 5/5 - 0s - 20ms/step - loss: 0.0087 - val_loss: 0.0164
# Epoch 5/75
# 5/5 - 0s - 18ms/step - loss: 0.0090 - val_loss: 0.0674
# Epoch 6/75
# 5/5 - 0s - 15ms/step - loss: 0.0161 - val_loss: 0.0202
# Epoch 7/75
# 5/5 - 0s - 20ms/step - loss: 0.0066 - val_loss: 0.0266
# Epoch 8/75
# 5/5 - 0s - 20ms/step - loss: 0.0088 - val_loss: 0.0196
# Epoch 9/75
# 5/5 - 0s - 20ms/step - loss: 0.0072 - val_loss: 0.0165
# Epoch 10/75
# 5/5 - 0s - 16ms/step - loss: 0.0142 - val_loss: 0.0414
# Epoch 11/75
# 5/5 - 0s - 20ms/step - loss: 0.0104 - val_loss: 0.0199
# Epoch 12/75
# 5/5 - 0s - 17ms/step - loss: 0.0066 - val_loss: 0.0213
# Epoch 13/75
# 5/5 - 0s - 18ms/step - loss: 0.0079 - val_loss: 0.0165
# Epoch 14/75
# 5/5 - 0s - 16ms/step - loss: 0.0085 - val_loss: 0.0633
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Outlier Threshold: 0.15
# Epoch 1/75
# 5/5 - 0s - 27ms/step - loss: 0.0119 - val_loss: 0.0573
# Epoch 2/75
# 5/5 - 0s - 21ms/step - loss: 0.0140 - val_loss: 0.0228
# Epoch 3/75
# 5/5 - 0s - 20ms/step - loss: 0.0071 - val_loss: 0.0276
# Epoch 4/75
# 5/5 - 0s - 17ms/step - loss: 0.0120 - val_loss: 0.0173
# Epoch 5/75
# 5/5 - 0s - 20ms/step - loss: 0.0064 - val_loss: 0.0230
# Epoch 6/75
# 5/5 - 0s - 36ms/step - loss: 0.0088 - val_loss: 0.0169
# Epoch 7/75
# 5/5 - 0s - 20ms/step - loss: 0.0064 - val_loss: 0.0220
# Epoch 8/75
# 5/5 - 0s - 19ms/step - loss: 0.0117 - val_loss: 0.0146
# Epoch 9/75
# 5/5 - 0s - 30ms/step - loss: 0.0081 - val_loss: 0.0431
# Epoch 10/75
# 5/5 - 0s - 32ms/step - loss: 0.0129 - val_loss: 0.0204
# Epoch 11/75
# 5/5 - 0s - 16ms/step - loss: 0.0077 - val_loss: 0.0349
# Epoch 12/75
# 5/5 - 0s - 16ms/step - loss: 0.0098 - val_loss: 0.0194
# Epoch 13/75
# 5/5 - 0s - 17ms/step - loss: 0.0071 - val_loss: 0.0429
# Epoch 14/75
# 5/5 - 0s - 17ms/step - loss: 0.0122 - val_loss: 0.0188
# Epoch 15/75
# 5/5 - 0s - 20ms/step - loss: 0.0071 - val_loss: 0.0240
# Epoch 16/75
# 5/5 - 0s - 17ms/step - loss: 0.0085 - val_loss: 0.0185
# Epoch 17/75
# 5/5 - 0s - 20ms/step - loss: 0.0091 - val_loss: 0.0138
# Epoch 18/75
# 5/5 - 0s - 19ms/step - loss: 0.0138 - val_loss: 0.0327
# Epoch 19/75
# 5/5 - 0s - 20ms/step - loss: 0.0082 - val_loss: 0.0312
# Epoch 20/75
# 5/5 - 0s - 19ms/step - loss: 0.0087 - val_loss: 0.0191
# Epoch 21/75
# 5/5 - 0s - 15ms/step - loss: 0.0065 - val_loss: 0.0187
# Epoch 22/75
# 5/5 - 0s - 17ms/step - loss: 0.0075 - val_loss: 0.0402
# Epoch 23/75
# 5/5 - 0s - 29ms/step - loss: 0.0126 - val_loss: 0.0189
# Epoch 24/75
# 5/5 - 0s - 20ms/step - loss: 0.0055 - val_loss: 0.0248
# Epoch 25/75
# 5/5 - 0s - 20ms/step - loss: 0.0079 - val_loss: 0.0229
# Epoch 26/75
# 5/5 - 0s - 29ms/step - loss: 0.0094 - val_loss: 0.0141
# Epoch 27/75
# 5/5 - 0s - 34ms/step - loss: 0.0097 - val_loss: 0.0381
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Outlier Threshold: 0.2
# Epoch 1/75
# 5/5 - 0s - 27ms/step - loss: 0.0253 - val_loss: 0.0572
# Epoch 2/75
# 5/5 - 0s - 57ms/step - loss: 0.0173 - val_loss: 0.0551
# Epoch 3/75
# 5/5 - 0s - 30ms/step - loss: 0.0168 - val_loss: 0.0566
# Epoch 4/75
# 5/5 - 0s - 22ms/step - loss: 0.0145 - val_loss: 0.0512
# Epoch 5/75
# 5/5 - 0s - 16ms/step - loss: 0.0189 - val_loss: 0.0545
# Epoch 6/75
# 5/5 - 0s - 17ms/step - loss: 0.0148 - val_loss: 0.0503
# Epoch 7/75
# 5/5 - 0s - 20ms/step - loss: 0.0156 - val_loss: 0.0522
# Epoch 8/75
# 5/5 - 0s - 17ms/step - loss: 0.0136 - val_loss: 0.0508
# Epoch 9/75
# 5/5 - 0s - 17ms/step - loss: 0.0213 - val_loss: 0.0475
# Epoch 10/75
# 5/5 - 0s - 20ms/step - loss: 0.0154 - val_loss: 0.0484
# Epoch 11/75
# 5/5 - 0s - 24ms/step - loss: 0.0155 - val_loss: 0.0463
# Epoch 12/75
# 5/5 - 0s - 16ms/step - loss: 0.0203 - val_loss: 0.0478
# Epoch 13/75
# 5/5 - 0s - 20ms/step - loss: 0.0133 - val_loss: 0.0449
# Epoch 14/75
# 5/5 - 0s - 16ms/step - loss: 0.0170 - val_loss: 0.0485
# Epoch 15/75
# 5/5 - 0s - 33ms/step - loss: 0.0157 - val_loss: 0.0457
# Epoch 16/75
# 5/5 - 0s - 32ms/step - loss: 0.0176 - val_loss: 0.0447
# Epoch 17/75
# 5/5 - 0s - 34ms/step - loss: 0.0146 - val_loss: 0.0435
# Epoch 18/75
# 5/5 - 0s - 32ms/step - loss: 0.0167 - val_loss: 0.0447
# Epoch 19/75
# 5/5 - 0s - 18ms/step - loss: 0.0125 - val_loss: 0.0432
# Epoch 20/75
# 5/5 - 0s - 26ms/step - loss: 0.0172 - val_loss: 0.0479
# Epoch 21/75
# 5/5 - 0s - 17ms/step - loss: 0.0134 - val_loss: 0.0437
# Epoch 22/75
# 5/5 - 0s - 17ms/step - loss: 0.0183 - val_loss: 0.0433
# Epoch 23/75
# 5/5 - 0s - 20ms/step - loss: 0.0149 - val_loss: 0.0429
# Epoch 24/75
# 5/5 - 0s - 17ms/step - loss: 0.0136 - val_loss: 0.0431
# Epoch 25/75
# 5/5 - 0s - 36ms/step - loss: 0.0132 - val_loss: 0.0452
# Epoch 26/75
# 5/5 - 0s - 23ms/step - loss: 0.0175 - val_loss: 0.0468
# Epoch 27/75
# 5/5 - 0s - 20ms/step - loss: 0.0168 - val_loss: 0.0428
# Epoch 28/75
# 5/5 - 0s - 20ms/step - loss: 0.0147 - val_loss: 0.0424
# Epoch 29/75
# 5/5 - 0s - 20ms/step - loss: 0.0130 - val_loss: 0.0421
# Epoch 30/75
# 5/5 - 0s - 19ms/step - loss: 0.0166 - val_loss: 0.0461
# Epoch 31/75
# 5/5 - 0s - 18ms/step - loss: 0.0137 - val_loss: 0.0421
# Epoch 32/75
# 5/5 - 0s - 17ms/step - loss: 0.0141 - val_loss: 0.0445
# Epoch 33/75
# 5/5 - 0s - 17ms/step - loss: 0.0122 - val_loss: 0.0428
# Epoch 34/75
# 5/5 - 0s - 20ms/step - loss: 0.0129 - val_loss: 0.0428
# Epoch 35/75
# 5/5 - 0s - 17ms/step - loss: 0.0131 - val_loss: 0.0410
# Epoch 36/75
# 5/5 - 0s - 19ms/step - loss: 0.0180 - val_loss: 0.0443
# Epoch 37/75
# 5/5 - 0s - 20ms/step - loss: 0.0132 - val_loss: 0.0416
# Epoch 38/75
# 5/5 - 0s - 20ms/step - loss: 0.0141 - val_loss: 0.0464
# Epoch 39/75
# 5/5 - 0s - 30ms/step - loss: 0.0141 - val_loss: 0.0426
# Epoch 40/75
# 5/5 - 0s - 18ms/step - loss: 0.0162 - val_loss: 0.0430
# Epoch 41/75
# 5/5 - 0s - 17ms/step - loss: 0.0131 - val_loss: 0.0414
# Epoch 42/75
# 5/5 - 0s - 20ms/step - loss: 0.0146 - val_loss: 0.0494
# Epoch 43/75
# 5/5 - 0s - 19ms/step - loss: 0.0147 - val_loss: 0.0429
# Epoch 44/75
# 5/5 - 0s - 29ms/step - loss: 0.0157 - val_loss: 0.0443
# Epoch 45/75
# 5/5 - 0s - 18ms/step - loss: 0.0130 - val_loss: 0.0423
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# File: ../data/data_cleaned_LASSO.csv, Outlier Threshold: nan -> Errors: {'MAPE': 1.8524871, 'RMSE': 49376.723, 'MAE': 37868.414}
# File: ../data/data_cleaned_LASSO.csv, Outlier Threshold: 0.05 -> Errors: {'MAPE': 1.5311929, 'RMSE': 45971.51, 'MAE': 35612.805}
# File: ../data/data_cleaned_LASSO.csv, Outlier Threshold: 0.1 -> Errors: {'MAPE': 1.3755577, 'RMSE': 25924.264, 'MAE': 20804.95}
# File: ../data/data_cleaned_LASSO.csv, Outlier Threshold: 0.15 -> Errors: {'MAPE': 2.2431517, 'RMSE': 23950.594, 'MAE': 19591.242}
# File: ../data/data_cleaned_LASSO.csv, Outlier Threshold: 0.2 -> Errors: {'MAPE': 1.224133, 'RMSE': 18526.266, 'MAE': 15323.695}

# %%
print(errors_dict)
# Out:
# {('../data/data_cleaned_LASSO.csv', nan): {'MAPE': 1.8524871, 'RMSE': 49376.723, 'MAE': 37868.414}, ('../data/data_cleaned_LASSO.csv', 0.05): {'MAPE': 1.5311929, 'RMSE': 45971.51, 'MAE': 35612.805}, ('../data/data_cleaned_LASSO.csv', 0.1): {'MAPE': 1.3755577, 'RMSE': 25924.264, 'MAE': 20804.95}, ('../data/data_cleaned_LASSO.csv', 0.15): {'MAPE': 2.2431517, 'RMSE': 23950.594, 'MAE': 19591.242}, ('../data/data_cleaned_LASSO.csv', 0.2): {'MAPE': 1.224133, 'RMSE': 18526.266, 'MAE': 15323.695}}
